# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# ✅ Echo State Network (ESN) implementation
class ESN:
    def __init__(self, n_inputs, n_outputs, n_reservoir=100, spectral_radius=0.95,
                 sparsity=0.1, random_state=None):
        self.n_inputs = n_inputs
        self.n_outputs = n_outputs
        self.n_reservoir = n_reservoir
        self.spectral_radius = spectral_radius
        self.sparsity = sparsity
        self.random_state = np.random.RandomState(random_state)

        self._Win = self.random_state.rand(self.n_reservoir, self.n_inputs) - 0.5
        W = self.random_state.rand(self.n_reservoir, self.n_reservoir) - 0.5

        # Apply sparsity
        W[self.random_state.rand(*W.shape) > self.sparsity] = 0

        # Spectral radius adjustment
        radius = np.max(np.abs(np.linalg.eigvals(W)))
        self._W = W * (self.spectral_radius / radius)

    def _update(self, state, input_signal):
        pre_activation = np.dot(self._Win, input_signal) + np.dot(self._W, state)
        return np.tanh(pre_activation)

    def fit(self, X, y):
        states = np.zeros((X.shape[0], self.n_reservoir))
        state = np.zeros(self.n_reservoir)

        for t in range(X.shape[0]):
            state = self._update(state, X[t])
            states[t] = state

        # Ridge regression (simple)
        self._Wout = np.dot(np.linalg.pinv(states), y)

    def predict(self, X):
        predictions = []
        state = np.zeros(self.n_reservoir)

        for t in range(X.shape[0]):
            state = self._update(state, X[t])
            y = np.dot(self._Wout, state)
            predictions.append(y)

        return np.array(predictions)


# ✅ 1. Generate sine wave data
time = np.arange(0, 100, 0.1)
series = np.sin(time)


# ✅ 2. Prepare dataset using sliding window
def create_dataset(data, window=20):
    X, y = [], []
    for i in range(len(data) - window):
        X.append(data[i:i+window])
        y.append(data[i+window])
    return np.array(X), np.array(y)


window_size = 20
X, y = create_dataset(series, window=window_size)

X = X.reshape(X.shape[0], window_size, 1)

# Split into training and testing sets
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]


# ✅ 3. LSTM model
lstm = Sequential([
    LSTM(50, input_shape=(window_size, 1)),
    Dense(1)
])

lstm.compile(optimizer='adam', loss='mse')
lstm.fit(X_train, y_train, epochs=10, batch_size=32)

# Predict with LSTM
lstm_pred = lstm.predict(X_test).flatten()


# ✅ 4. ESN model (reshape input for ESN)
X_esn = X.reshape(X.shape[0], window_size)
X_train_esn, X_test_esn = X_esn[:split], X_esn[split:]

esn = ESN(n_inputs=window_size, n_outputs=1, n_reservoir=100, random_state=42)
esn.fit(X_train_esn, y_train)

esn_pred = esn.predict(X_test_esn)


# ✅ 5. Compare and plot
print("LSTM MSE:", mean_squared_error(y_test, lstm_pred))
print("ESN MSE:", mean_squared_error(y_test, esn_pred))

plt.plot(y_test, label="True")
plt.plot(lstm_pred, label="LSTM")
plt.plot(esn_pred, label="ESN")
plt.legend()
plt.title("LSTM vs ESN on Sine Wave Prediction")
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.3791
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0727
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1895e-04
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1528e-04
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7039e-04
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4687e-04
# Epoch 8/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1550e-04
# Epoch 9/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.9866e-05
# Epoch 10/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8064e-05
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
# LSTM MSE: 6.282475126129217e-05
# ESN MSE: 2.5677336224077698e-05
